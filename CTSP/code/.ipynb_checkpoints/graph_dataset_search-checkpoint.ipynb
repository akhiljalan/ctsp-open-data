# %%
from urllib import request
import lxml
from lxml import html
import Utils as utils
import re

# %%
def stop(url):
    """
    This helper function will return true when the url
    contains '/data' at the end. 
    """
    return url[-5:] == '/data'

# %%
def stop_tests():
    """
    This function will test the stopping function. 
    """
    assert(stop('https://data.cityofberkeley.info/311/311-Cases/k489-uv4i/data'), True)
    assert(stop('https://data.cityofberkeley.info/311/311-Cases/k489-uv4i'), False)
    print("All Tests Passed!")
stop_tests()
# Out:
# All Tests Passed!
# <ipython-input-3-9b4c3fab3d58>:5: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(stop('https://data.cityofberkeley.info/311/311-Cases/k489-uv4i/data'), True)
# <ipython-input-3-9b4c3fab3d58>:6: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(stop('https://data.cityofberkeley.info/311/311-Cases/k489-uv4i'), False)

# %%
def prune(url, browse_boolean):
    """
    This function will return true when the graph should continue searching
    and false when the graph should stop. 
    """
    url = url.lower().strip()
#     if 'data' not in url:
#         return False 
    if 'linkedin'in url:
        return False
    elif 'twitter' in url:
        return False
    elif 'socrata' in url:
        return False
    elif 'login' in url:
        return False
    elif 'mail' in url:
        return False
    else:
        return ((browse_boolean and (('browse' not in url) or ('page' in url))) or not browse_boolean)
#     if 'support' in url:
#         return False
#     if 'dev' in url:
#         return False
#     if 'mozilla' in url:
#         return False
#     if 'wiki' in url:
#         return False
#     if 'javascript' in url or 'microsoft' in url or 'xbox' in url or 'facebook' in url:
#         return False
#     if 'adobe' in url:
#         return False
#     if '#' in url:
#         return False
#     if 'home' in url:
#         return False
#     if 'twitter' in url:
#         return False
#     if not 'data' in url:
#         return False

# %%
prune('https://data.sfgov.org/City-Management-and-Ethics/Gifts-of-Travel-Contributors/hpj3-vnwh', False)
# Out:
# True

# %%
def search(url, add_to_url = 'browse?limitTo=datasets&utf8', browse_boolean = False, data_set_list = []):
    """
    This function will recursively search through the 
    web graph in order to find the datasets
    """
    url = url + add_to_url
    url_list = []
    print("rEcUrSiOn")
    ds_len = 299
    pattern = re.compile(r'/([a-z]|[0-9]){4}-([a-z]|[0-9]){4}')
    try:
        http_response = request.urlopen(url)
        open_response = http_response.read().decode('utf-8')
        raw_html = lxml.html.fromstring(open_response)
    except:
        return data_set_list
    for link in raw_html.xpath('//a/@href'):
        if '#' in link:
            continue
        if ('limit' in link and add_to_url == ''):
            continue
        if link[-1:] == '#':
            continue
        if link in url:
            continue
        if "http" not in link:
            link = url + link
        else:
            if pattern.match(link[-10:]) is not None and 'socrata' not in link.lower():
                print("Made it:{}".format(link))
                data_set_list += [link]
                continue
            else:
                continue
        if not prune(link, browse_boolean):
            continue
        if 'browse' in url:
            browse_boolean = True
        url_list += [link]
    if len(data_set_list) == ds_len:
        return data_set_list
    
    for link in url_list:
        print(link)
        data_set_list += search(link,'', True, [])
    return data_set_list

# %%
ds = search('https://data.sfgov.org/')
ds
# Out:
# rEcUrSiOn
# Made it:https://data.sfgov.org/City-Management-and-Ethics/Spending-And-Revenue/bpnb-jwfb
# Made it:https://data.sfgov.org/Housing-and-Buildings/Building-Permits/i98e-djp9
# https://data.sfgov.org/browse?limitTo=datasets&utf8/browse?limitTo=datasets&utf8=&page=4
# rEcUrSiOn
# Made it:https://data.sfgov.org/Public-Safety/Police-Department-Calls-for-Service/hz9m-tj6z
# Made it:https://data.sfgov.org/Economy-and-Community/Mobile-Food-Schedule/jjew-r69b
# Made it:https://data.sfgov.org/d/rqzj-sfat
# Made it:https://data.sfgov.org/City-Management-and-Ethics/Employee-Compensation/88g8-5mnd
# Made it:https://data.sfgov.org/Transportation/Air-Traffic-Passenger-Statistics/rkru-6vcg
# Made it:https://data.sfgov.org/Culture-and-Recreation/SF-Civic-Art-Collection/zfw6-95su
# Made it:https://data.sfgov.org/Geographic-Locations-and-Boundaries/List-of-Streets-and-Intersections/pu5n-qu5c
# Made it:https://data.sfgov.org/Housing-and-Buildings/Buyout-agreements/wmam-7g8d
# Made it:https://data.sfgov.org/City-Management-and-Ethics/Budget/xdgd-c79v
# Made it:https://data.sfgov.org/City-Management-and-Ethics/Vendor-Payments-Purchase-Order-Summary-/p5r5-fd7g
# Made it:https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-FPPC-Form-497-Late-Contribution-R/xdap-cuq4
# Made it:https://data.sfgov.org/Ethics/Campaign-Finance-Data-Key/wygs-cc76
# https://data.sfgov.org/browse?limitTo=datasets&utf8/browse?limitTo=datasets&utf8=&page=5
# rEcUrSiOn
# Made it:https://data.sfgov.org/City-Management-and-Ethics/Scorecard-Measures/kc49-udxn
# Made it:https://data.sfgov.org/City-Management-and-Ethics/Dataset-inventory/y8fp-fbf5
# Made it:https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-Data-Key/wygs-cc76
# Made it:https://data.sfgov.org/Transportation/2011-SFO-Customer-Survey/v94x-pf9r
# Made it:https://data.sfgov.org/City-Infrastructure/Utility-Excavation-Moratorium-Streets/5wbp-dwzt
# Made it:https://data.sfgov.org/City-Infrastructure/Envista-Projects-for-Utility-Excavation-and-Paving/sf93-6dmr
# Made it:https://data.sfgov.org/City-Infrastructure/City-Facilities/nc68-ngbr
# Made it:https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-FPPC-Form-460-Schedule-E-Payments/hc26-j9if
# Made it:https://data.sfgov.org/Ethics/Campaign-Finance-Data-Key/wygs-cc76
# Made it:https://data.sfgov.org/City-Infrastructure/Curb-Ramps/ch9w-7kih
# Made it:https://data.sfgov.org/City-Management-and-Ethics/Full-Time-Employees-By-Job-Classification/uk3k-9ai5
# https://data.sfgov.org/browse?limitTo=datasets&utf8/browse?limitTo=datasets&utf8=&page=6
# rEcUrSiOn
# Made it:https://data.sfgov.org/Housing-and-Buildings/Affordable-Housing-Pipeline/aaxw-2cb8
# Made it:https://data.sfgov.org/Housing-and-Buildings/SF-Development-Pipeline-2016-Q1/dtz9-jkjt
# Made it:https://data.sfgov.org/Geographic-Locations-and-Boundaries/Addresses-Enterprise-Addressing-System/sr5d-tnui
# Made it:https://data.sfgov.org/City-Infrastructure/Envista-Projects-for-Paving/bxqh-5px8
# Made it:https://data.sfgov.org/City-Management-and-Ethics/-Known-Issue-Lobbyist-Activity-Political-Contribut/sa8r-purn
# Made it:https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance
# Made it:https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-FPPC-Form-496-Late-Independent-Ex/4fd4-wqps
# Made it:https://data.sfgov.org/Ethics/Campaign-Finance-Data-Key/wygs-cc76
# Made it:https://data.sfgov.org/Housing-and-Buildings/Petitions-to-the-Rent-Board/6swy-cmkq
# Made it:https://data.sfgov.org/City-Management-and-Ethics/Job-Titles-by-Classification/58un-vqfs
# Made it:https://data.sfgov.org/Housing-and-Buildings/SF-Development-Pipeline-2014-Q4/858q-nwrm
# Made it:https://data.sfgov.org/Housing-and-Buildings/Residential-Projects-With-Inclusionary-Requirement/nj3x-rw36
# Made it:https://data.sfgov.org/Housing-and-Buildings/2013-Housing-Inventory/e7d3-dxh5
# Made it:https://data.sfgov.org/Health-and-Social-Services/Health-Care-Facilities/jhsu-2pka
# https://data.sfgov.org/browse?limitTo=datasets&utf8/browse?limitTo=datasets&utf8=&page=2
# rEcUrSiOn
# Made it:https://data.sfgov.org/City-Infrastructure/Street-Tree-List/tkzw-k3nq
# Made it:https://data.sfgov.org/City-Management-and-Ethics/-Known-Issue-Lobbyist-Activity-Contacts-of-Public-/hr5m-xnxc
# Made it:https://data.sfgov.org/Housing-and-Buildings/Eviction-Notices/5cei-gny5
# Made it:https://data.sfgov.org/Public-Safety/Fire-Incidents/wr8u-xric
# Made it:https://data.sfgov.org/City-Management-and-Ethics/Dataset-Alerts/vx35-bnbs
# Made it:https://data.sfgov.org/City-Infrastructure/311-Top-Articles-Referenced-historical-through-Aug/hrr4-hjc6
# Made it:https://data.sfgov.org/City-Management-and-Ethics/311-Top-Articles-Referenced/3tsy-c2sd
# Made it:https://data.sfgov.org/Geographic-Locations-and-Boundaries/Addresses-with-Units-Enterprise-Addressing-System-/dxjs-vqsy
# Made it:https://data.sfgov.org/City-Infrastructure/311-Call-Metrics-by-Month/mwjb-biik
# Made it:https://data.sfgov.org/City-Infrastructure/Street-Use-Permits/b6tj-gt35
# Made it:https://data.sfgov.org/Health-and-Social-Services/Restaurant-Scores-LIVES-Standard/pyih-qa8i
# https://data.sfgov.org/browse?limitTo=datasets&utf8/browse?limitTo=datasets&utf8=&page=30
# rEcUrSiOn
# Made it:https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-List-Of-Candidates-Running-For-Of/uvqv-zi4r
# Made it:https://data.sfgov.org/City-Infrastructure/Open-Data-Portal-Dataset-Attachments/a2hm-yzs6
# Made it:https://data.sfgov.org/Transportation/2015-SFO-Customer-Survey/6h3c-wyfe
# Made it:https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-Status-Of-Voluntary-Expenditure-C/ct8k-kggq
# Made it:https://data.sfgov.org/City-Infrastructure/Proposed-Commercial-Wireless-Telecommunication-Ser/8zki-wqj3
# Made it:https://data.sfgov.org/Transportation/2010-SFO-Customer-Survey/3g5j-aamw
# Made it:https://data.sfgov.org/Housing-and-Buildings/Electrical-Permits-Contacts/fdm7-jqqf
# Made it:https://data.sfgov.org/City-Infrastructure/City-Sub-Facilities/qvpz-vw28
# Made it:https://data.sfgov.org/City-Infrastructure/TI-Report/vsrb-4rhy
# ['https://data.sfgov.org/Culture-and-Recreation/Film-Locations-in-San-Francisco/yitu-d5am',
#  'https://data.sfgov.org/Public-Safety/-Change-Notice-Police-Department-Incidents/tmnf-yvry',
#  'https://data.sfgov.org/Economy-and-Community/Registered-Business-Locations-San-Francisco/g8m3-pdis',
#  'https://data.sfgov.org/City-Infrastructure/311-Cases/vw6y-z8j6',
#  'https://data.sfgov.org/Health-and-Social-Services/HSA-90-day-emergency-shelter-waitlist/w4sk-nq57',
#  'https://data.sfgov.org/Geographic-Locations-and-Boundaries/Street-Names/6d9h-4u5v',
#  'https://data.sfgov.org/Economy-and-Community/Mobile-Food-Facility-Permit/rqzj-sfat',
#  'https://data.sfgov.org/d/jjew-r69b',
#  'https://data.sfgov.org/Energy-and-Environment/Existing-Commercial-Buildings-Energy-Performance-O/j2j3-acqj',
#  'https://data.sfgov.org/Energy-and-Environment/Existing-Commercial-Buildings-Energy-Performance-O/v3c6-n4qs',
#  'https://data.sfgov.org/Public-Safety/Fire-Department-Calls-for-Service/nuek-vuh3',
#  'https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-FPPC-Form-460-Summary-Totals/4tts-fyix',
#  'https://data.sfgov.org/Ethics/Campaign-Finance-Data-Key/wygs-cc76',
#  'https://data.sfgov.org/Transportation/2010-SFO-Customer-Survey/3g5j-aamw',
#  'https://data.sfgov.org/Housing-and-Buildings/2011-Housing-Inventory/mpcm-79w2',
#  'https://data.sfgov.org/Transportation/2011-SFO-Customer-Survey/v94x-pf9r',
#  'https://data.sfgov.org/Housing-and-Buildings/2012-Housing-Inventory/4xa2-t52k',
#  'https://data.sfgov.org/Transportation/2012-SFO-Customer-Survey/ckai-dve4',
#  'https://data.sfgov.org/Housing-and-Buildings/2013-Housing-Inventory/e7d3-dxh5',
#  'https://data.sfgov.org/Transportation/2013-SFO-Customer-Survey/mjr8-p6m5',
#  'https://data.sfgov.org/Housing-and-Buildings/2014-Housing-Inventory/b8d6-zthg',
#  'https://data.sfgov.org/Transportation/2014-SFO-Customer-Survey/xr4w-bx78',
#  'https://data.sfgov.org/City-Infrastructure/2015-Project-Appendix/xpdk-pzjd',
#  'https://data.sfgov.org/Culture-and-Recreation/Film-Locations-in-San-Francisco/yitu-d5am',
#  'https://data.sfgov.org/Public-Safety/-Change-Notice-Police-Department-Incidents/tmnf-yvry',
#  'https://data.sfgov.org/Economy-and-Community/Registered-Business-Locations-San-Francisco/g8m3-pdis',
#  'https://data.sfgov.org/City-Infrastructure/311-Cases/vw6y-z8j6',
#  'https://data.sfgov.org/Health-and-Social-Services/HSA-90-day-emergency-shelter-waitlist/w4sk-nq57',
#  'https://data.sfgov.org/Geographic-Locations-and-Boundaries/Street-Names/6d9h-4u5v',
#  'https://data.sfgov.org/Economy-and-Community/Mobile-Food-Facility-Permit/rqzj-sfat',
#  'https://data.sfgov.org/d/jjew-r69b',
#  'https://data.sfgov.org/Energy-and-Environment/Existing-Commercial-Buildings-Energy-Performance-O/j2j3-acqj',
#  'https://data.sfgov.org/Energy-and-Environment/Existing-Commercial-Buildings-Energy-Performance-O/v3c6-n4qs',
#  'https://data.sfgov.org/Public-Safety/Fire-Department-Calls-for-Service/nuek-vuh3',
#  'https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-FPPC-Form-460-Summary-Totals/4tts-fyix',
#  'https://data.sfgov.org/Ethics/Campaign-Finance-Data-Key/wygs-cc76',
#  'https://data.sfgov.org/City-Infrastructure/Street-Tree-List/tkzw-k3nq',
#  'https://data.sfgov.org/City-Management-and-Ethics/-Known-Issue-Lobbyist-Activity-Contacts-of-Public-/hr5m-xnxc',
#  'https://data.sfgov.org/Housing-and-Buildings/Eviction-Notices/5cei-gny5',
#  'https://data.sfgov.org/Public-Safety/Fire-Incidents/wr8u-xric',
#  'https://data.sfgov.org/City-Management-and-Ethics/Dataset-Alerts/vx35-bnbs',
#  'https://data.sfgov.org/City-Infrastructure/311-Top-Articles-Referenced-historical-through-Aug/hrr4-hjc6',
#  'https://data.sfgov.org/City-Management-and-Ethics/311-Top-Articles-Referenced/3tsy-c2sd',
#  'https://data.sfgov.org/Geographic-Locations-and-Boundaries/Addresses-with-Units-Enterprise-Addressing-System-/dxjs-vqsy',
#  'https://data.sfgov.org/City-Infrastructure/311-Call-Metrics-by-Month/mwjb-biik',
#  'https://data.sfgov.org/City-Infrastructure/Street-Use-Permits/b6tj-gt35',
#  'https://data.sfgov.org/Health-and-Social-Services/Restaurant-Scores-LIVES-Standard/pyih-qa8i',
#  'https://data.sfgov.org/Housing-and-Buildings/Assessor-Historical-Secured-Property-Tax-Rolls/wv5m-vpq2',
#  'https://data.sfgov.org/City-Management-and-Ethics/Salary-Ranges-by-Job-Classification/7h4w-reyq',
#  'https://data.sfgov.org/City-Management-and-Ethics/Expenditure-Lobbyists-Registration-and-Monthly-Dis/nkxk-d459',
#  'https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-FPPC-Form-460-Schedule-A-Monetary/q66q-d2tr',
#  'https://data.sfgov.org/Ethics/Campaign-Finance-Data-Key/wygs-cc76',
#  'https://data.sfgov.org/Geographic-Locations-and-Boundaries/Supervisor-District-to-ZIP-Code-Crosswalk/v22h-ujnv',
#  'https://data.sfgov.org/Housing-and-Buildings/Mayor-s-Office-of-Housing-and-Community-Developmen/9rdx-httc',
#  'https://data.sfgov.org/City-Management-and-Ethics/Lobbyists-on-Behalf-of-the-City-Disclosure-Reports/sz7b-c3pn',
#  'https://data.sfgov.org/Culture-and-Recreation/Recreation-Park-Department-Park-Info-Dataset/z76i-7s65',
#  'https://data.sfgov.org/City-Management-and-Ethics/Spending-And-Revenue/bpnb-jwfb',
#  'https://data.sfgov.org/Housing-and-Buildings/Building-Permits/i98e-djp9',
#  'https://data.sfgov.org/Public-Safety/Police-Department-Calls-for-Service/hz9m-tj6z',
#  'https://data.sfgov.org/Economy-and-Community/Mobile-Food-Schedule/jjew-r69b',
#  'https://data.sfgov.org/d/rqzj-sfat',
#  'https://data.sfgov.org/City-Management-and-Ethics/Employee-Compensation/88g8-5mnd',
#  'https://data.sfgov.org/Transportation/Air-Traffic-Passenger-Statistics/rkru-6vcg',
#  'https://data.sfgov.org/Culture-and-Recreation/SF-Civic-Art-Collection/zfw6-95su',
#  'https://data.sfgov.org/Geographic-Locations-and-Boundaries/List-of-Streets-and-Intersections/pu5n-qu5c',
#  'https://data.sfgov.org/Housing-and-Buildings/Buyout-agreements/wmam-7g8d',
#  'https://data.sfgov.org/City-Management-and-Ethics/Budget/xdgd-c79v',
#  'https://data.sfgov.org/City-Management-and-Ethics/Vendor-Payments-Purchase-Order-Summary-/p5r5-fd7g',
#  'https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-FPPC-Form-497-Late-Contribution-R/xdap-cuq4',
#  'https://data.sfgov.org/Ethics/Campaign-Finance-Data-Key/wygs-cc76',
#  'https://data.sfgov.org/City-Management-and-Ethics/Scorecard-Measures/kc49-udxn',
#  'https://data.sfgov.org/City-Management-and-Ethics/Dataset-inventory/y8fp-fbf5',
#  'https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-Data-Key/wygs-cc76',
#  'https://data.sfgov.org/Transportation/2011-SFO-Customer-Survey/v94x-pf9r',
#  'https://data.sfgov.org/City-Infrastructure/Utility-Excavation-Moratorium-Streets/5wbp-dwzt',
#  'https://data.sfgov.org/City-Infrastructure/Envista-Projects-for-Utility-Excavation-and-Paving/sf93-6dmr',
#  'https://data.sfgov.org/City-Infrastructure/City-Facilities/nc68-ngbr',
#  'https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-FPPC-Form-460-Schedule-E-Payments/hc26-j9if',
#  'https://data.sfgov.org/Ethics/Campaign-Finance-Data-Key/wygs-cc76',
#  'https://data.sfgov.org/City-Infrastructure/Curb-Ramps/ch9w-7kih',
#  'https://data.sfgov.org/City-Management-and-Ethics/Full-Time-Employees-By-Job-Classification/uk3k-9ai5',
#  'https://data.sfgov.org/Housing-and-Buildings/Affordable-Housing-Pipeline/aaxw-2cb8',
#  'https://data.sfgov.org/Housing-and-Buildings/SF-Development-Pipeline-2016-Q1/dtz9-jkjt',
#  'https://data.sfgov.org/Geographic-Locations-and-Boundaries/Addresses-Enterprise-Addressing-System/sr5d-tnui',
#  'https://data.sfgov.org/City-Infrastructure/Envista-Projects-for-Paving/bxqh-5px8',
#  'https://data.sfgov.org/City-Management-and-Ethics/-Known-Issue-Lobbyist-Activity-Political-Contribut/sa8r-purn',
#  'https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-FPPC-Form-461-Major-Donor-and-Ind/86nq-bynj',
#  'https://data.sfgov.org/Ethics/Campaign-Finance-Data-Key/wygs-cc76',
#  'https://data.sfgov.org/City-Management-and-Ethics/-Known-Issue-Lobbyist-Activity-Payments-Promised-B/s2fy-y3my',
#  'https://data.sfgov.org/Transportation/Meter-Operating-Schedules/6cqg-dxku',
#  'https://data.sfgov.org/Health-and-Social-Services/Community-Resiliency-Indicator-System/banc-xdvr',
#  'https://data.sfgov.org/City-Infrastructure/Streets-Data-Pavement-Condition-Index-PCI-Scores/5aye-4rtt',
#  'https://data.sfgov.org/City-Infrastructure/Right-of-Way-Exception-Data/yrgu-vakm',
#  'https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-FPPC-Form-460-Schedule-G-Payments/6iqh-u3hk',
#  'https://data.sfgov.org/Ethics/Campaign-Finance-Data-Key/wygs-cc76',
#  'https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-FPPC-Form-460-Schedule-D-Summary-/i8us-xn7t',
#  'https://data.sfgov.org/Ethics/Campaign-Finance-Data-Key/wygs-cc76',
#  'https://data.sfgov.org/City-Infrastructure/Utility-Excavation-Permits/smdf-6c45',
#  'https://data.sfgov.org/Transportation/Air-Traffic-Landings-Statistics/fpux-q53t',
#  'https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-Filers-With-Delinquent-Campaign-F/jb8g-e374',
#  'https://data.sfgov.org/City-Management-and-Ethics/List-of-Historical-Ballot-Measures/xzie-ixjw',
#  'https://data.sfgov.org/Housing-and-Buildings/SF-Development-Pipeline-2017-Q1/7qzr-p6xn',
#  'https://data.sfgov.org/Transportation/Metered-motorcycle-spaces/uf55-k7py',
#  'https://data.sfgov.org/City-Infrastructure/Stormwater-inlets-drains-and-catch-basins/jtgq-b7c5',
#  'https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-SFEC-1-126-Notification-of-Contra/sn2k-q974',
#  'https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-FPPC-Form-460-Schedule-C-Non-Mone/k76b-4yme',
#  'https://data.sfgov.org/Ethics/Campaign-Finance-Data-Key/wygs-cc76',
#  'https://data.sfgov.org/Housing-and-Buildings/SF-Development-Pipeline-2012-Q1/v5p2-emnu',
#  'https://data.sfgov.org/Culture-and-Recreation/Current-San-Francisco-Advisories/qn4d-bra2',
#  'https://data.sfgov.org/Transportation/2013-SFO-Customer-Survey/mjr8-p6m5',
#  'https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-FPPC-Form-460-Schedule-F-Accrued-/tr8k-7cit',
#  'https://data.sfgov.org/Ethics/Campaign-Finance-Data-Key/wygs-cc76',
#  'https://data.sfgov.org/Economy-and-Community/Schools/tpp3-epx2',
#  'https://data.sfgov.org/Energy-and-Environment/San-Francisco-Municipal-Greenhouse-Gas-Inventory/pxac-sadh',
#  'https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-FPPC-Form-465-Supplemental-Indepe/pyxa-3r7p',
#  'https://data.sfgov.org/Ethics/Campaign-Finance-Data-Key/wygs-cc76',
#  'https://data.sfgov.org/Health-and-Social-Services/San-Francisco-Department-of-Public-Health-Flu-Shot/yg87-cd6v',
#  'https://data.sfgov.org/Energy-and-Environment/San-Francisco-Communitywide-Greenhouse-Gas-Invento/btm4-e4ak',
#  'https://data.sfgov.org/City-Infrastructure/Web-Analytics-for-SFGov-Sites-2015-Q1-Q2-Q3-Q4-/yrfc-c5yu',
#  'https://data.sfgov.org/Housing-and-Buildings/Fire-Violations/4zuq-2cbe',
#  'https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-FPPC-Form-496-Late-Independent-Ex/4fd4-wqps',
#  'https://data.sfgov.org/Ethics/Campaign-Finance-Data-Key/wygs-cc76',
#  'https://data.sfgov.org/Housing-and-Buildings/Petitions-to-the-Rent-Board/6swy-cmkq',
#  'https://data.sfgov.org/City-Management-and-Ethics/Job-Titles-by-Classification/58un-vqfs',
#  'https://data.sfgov.org/Housing-and-Buildings/SF-Development-Pipeline-2014-Q4/858q-nwrm',
#  'https://data.sfgov.org/Housing-and-Buildings/Residential-Projects-With-Inclusionary-Requirement/nj3x-rw36',
#  'https://data.sfgov.org/Housing-and-Buildings/2013-Housing-Inventory/e7d3-dxh5',
#  'https://data.sfgov.org/Health-and-Social-Services/Health-Care-Facilities/jhsu-2pka',
#  'https://data.sfgov.org/City-Infrastructure/Street-Tree-List/tkzw-k3nq',
#  'https://data.sfgov.org/City-Management-and-Ethics/-Known-Issue-Lobbyist-Activity-Contacts-of-Public-/hr5m-xnxc',
#  'https://data.sfgov.org/Housing-and-Buildings/Eviction-Notices/5cei-gny5',
#  'https://data.sfgov.org/Public-Safety/Fire-Incidents/wr8u-xric',
#  'https://data.sfgov.org/City-Management-and-Ethics/Dataset-Alerts/vx35-bnbs',
#  'https://data.sfgov.org/City-Infrastructure/311-Top-Articles-Referenced-historical-through-Aug/hrr4-hjc6',
#  'https://data.sfgov.org/City-Management-and-Ethics/311-Top-Articles-Referenced/3tsy-c2sd',
#  'https://data.sfgov.org/Geographic-Locations-and-Boundaries/Addresses-with-Units-Enterprise-Addressing-System-/dxjs-vqsy',
#  'https://data.sfgov.org/City-Infrastructure/311-Call-Metrics-by-Month/mwjb-biik',
#  'https://data.sfgov.org/City-Infrastructure/Street-Use-Permits/b6tj-gt35',
#  'https://data.sfgov.org/Health-and-Social-Services/Restaurant-Scores-LIVES-Standard/pyih-qa8i',
#  'https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-List-Of-Candidates-Running-For-Of/uvqv-zi4r',
#  'https://data.sfgov.org/City-Infrastructure/Open-Data-Portal-Dataset-Attachments/a2hm-yzs6',
#  'https://data.sfgov.org/Transportation/2015-SFO-Customer-Survey/6h3c-wyfe',
#  'https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-Status-Of-Voluntary-Expenditure-C/ct8k-kggq',
#  'https://data.sfgov.org/City-Infrastructure/Proposed-Commercial-Wireless-Telecommunication-Ser/8zki-wqj3',
#  'https://data.sfgov.org/Transportation/2010-SFO-Customer-Survey/3g5j-aamw',
#  'https://data.sfgov.org/Housing-and-Buildings/Electrical-Permits-Contacts/fdm7-jqqf',
#  'https://data.sfgov.org/City-Infrastructure/City-Sub-Facilities/qvpz-vw28',
#  'https://data.sfgov.org/City-Infrastructure/TI-Report/vsrb-4rhy']

# %%
len(ds)
# Out:
# 148

# %% [raw]
# url[-9:]

# %%
prog = re.compile(r'([a-z]|[0-9]){4}-([a-z]|[0-9]){4}')
prog.match(url[-9:]) is not None
# Out:
# True

# %%
pattern = re.compile(r'/([a-z]|[0-9]){4}-([a-z]|[0-9]){4}')

# %%
link = 'https://data.sfgov.org/City-Management-and-Ethics/Campaign-Finance-Summary-Of-Third-Party-Disclosure/7i7v-m2wn'
pattern.match('/7i7v-m2wn') is not None
# Out:
# True
